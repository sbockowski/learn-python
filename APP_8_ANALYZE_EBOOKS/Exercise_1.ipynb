# %% [markdown]
# # Load the book

# %%
with open("miracle_in_the_andes.txt", "r") as file:
    book = file.read()

# %% [markdown]
# # Extract the paragraphs where "love" was used

# %%
import re
pattern = re.compile("[^\n]+love[^\n]+")
findings = re.findall(pattern, book)
findings[:2]
# Out:
# ['To me, this is the essence of rugby. No other sport gives you such an intense sense of selflessness and unified purpose. I believe this is why rugby players all over the world feel such a passion for the game and such a feeling of brotherhood. As a young man, of course, I could not put these things into words, but I knew, and my teammates knew, that there was something special about the game, and under the guidance of the Christian Brothers we developed a passionate love for the sport that shaped our friendships and our lives. For eight years we played our hearts out for the Christian Brothers—a brotherhood of young boys with Latin names, playing a game with deep Anglo roots under Uruguay’s sunny skies, and proudly wearing the bright green shamrock on our uniforms. The game became so much a part of our lives, in fact, that when we graduated from Stella Maris at the age of sixteen, many of us could not bear the thought that our playing days were over. Our salvation came in the form of the Old Christians Club, a private rugby team formed in 1965 by previous alumni of the Stella Maris rugby program to give Stella Maris ruggers a chance to continue playing the game after our school years ended.',
#  'There were others—Alexis Hounie, Gastón Costemalle, Daniel Shaw—all of them great players and all of them my friends. But my oldest friend was Guido Magri. He and I had met on my first day at the Stella Maris School—I was eight years old and Guido was one year older—and we had been inseparable ever since. Guido and I grew up together, playing soccer and sharing a love of motorcycles, cars, and auto racing. When I was fifteen we both had mopeds that we had modified in silly ways—removing the mufflers, turn signals, and fenders—and we would ride them to Las Delicias, a famous ice cream parlor in our neighborhood, where we would drool over the girls from the nearby School Sagrado Corazón, hoping to impress them with our souped-up scooters. Guido was a dependable friend, with a good sense of humor and an easy laugh. He was also an outstanding scrum half, as quick and smart as a fox, with good hands and great courage. Under the guidance of the Christian Brothers, both of us grew to love the game of rugby with a consuming passion. As seasons passed we worked hard to improve our skills, and by the time I was fifteen we had each earned a spot on the Stella Maris First XV, the team’s starting lineup. After graduation, both of us went on to join the Old Christians and spent several happy seasons pursuing the high-octane social life of young rugby players. That rowdiness came to an abrupt end for Guido in 1969, when he met and fell in love with the beautiful daughter of a Chilean diplomat. She was now his fiancée, and he was happy to behave himself for her sake.']

# %% [markdown]
# # Extract the chapter titles

# %%
pattern = re.compile("Chapter [0-9]\n*(.+)")
findings = re.findall(pattern, book)
findings
# Out:
# ['Before',
#  'Everything Precious',
#  'A Promise',
#  'Breathe Once More',
#  'Abandoned',
#  'Tomb',
#  'East',
#  'The Opposite of Death',
#  'I See a Man',
#  '0']

# %% [markdown]
# # Function that finds the occurence of any word

# %%
def find_word(w):
    pattern = re.compile("[a-zA-Z]+")
    findings = re.findall(pattern, book.lower())
    d = {}
    for word in findings:
        if word in d.keys():
            d[word] = d[word] + 1
            print(f"{word} już jest")
        else:
            d[word] = 1
            print(f"{word} dodane pierwszy raz")
    try:
        return d[w]
    except:
        return f'The book does not contain the word "{w}"'

# %% [markdown]
# # Call the function

# %%
find_word("chapter")
# Out:
# chapter dodane pierwszy raz
# before dodane pierwszy raz
# it dodane pierwszy raz
# was dodane pierwszy raz
# friday dodane pierwszy raz
# the dodane pierwszy raz
# thirteenth dodane pierwszy raz
# of dodane pierwszy raz
# october dodane pierwszy raz
# we dodane pierwszy raz
# joked dodane pierwszy raz
# about dodane pierwszy raz
# that dodane pierwszy raz
# flying dodane pierwszy raz
# over dodane pierwszy raz
# the już jest
# andes dodane pierwszy raz
# on dodane pierwszy raz
# such dodane pierwszy raz
# an dodane pierwszy raz
# unlucky dodane pierwszy raz
# day dodane pierwszy raz
# but dodane pierwszy raz
# young dodane pierwszy raz
# men dodane pierwszy raz
# make dodane pierwszy raz
# those dodane pierwszy raz
# kinds dodane pierwszy raz
# of już jest
# jokes dodane pierwszy raz
# so dodane pierwszy raz
# easily dodane pierwszy raz
# our dodane pierwszy raz
# flight dodane pierwszy raz
# had dodane pierwszy raz
# originated dodane pierwszy raz
# one dodane pierwszy raz
# day już jest
# earlier dodane pierwszy raz
# in dodane pierwszy raz
# montevideo dodane pierwszy raz
# my dodane pierwszy raz
# hometown dodane pierwszy raz
# its dodane pierwszy raz
# destination dodane pierwszy raz
# santiago dodane pierwszy raz
# chile dodane pierwszy raz
# it już jest
# was już jest
# a dodane pierwszy raz
# chartered dodane pierwszy raz
# flight już jest
# on już jest
# a już jest
# fairchild dodane pierwszy raz
# twin dodane pierwszy raz
# engine dodane pierwszy raz
# turboprop dodane pierwszy raz
# carrying dodane pierwszy raz
# my już jest
# rugby dodane pierwszy raz
# team dodane pierwszy raz
# the już jest
# old dodane pierwszy raz
# christians dodane pierwszy raz
# rugby już jest
# club dodane pierwszy raz
# to dodane pierwszy raz
# play dodane pierwszy raz
# an już jest
# exhibition dodane pierwszy raz
# match dodane pierwszy raz
# against dodane pierwszy raz
# a już jest
# top dodane pierwszy raz
# chilean dodane pierwszy raz
# squad dodane pierwszy raz
# there dodane pierwszy raz
# were dodane pierwszy raz
# forty dodane pierwszy raz
# five dodane pierwszy raz
# people dodane pierwszy raz
# aboard dodane pierwszy raz
# including dodane pierwszy raz
# four dodane pierwszy raz
# crew dodane pierwszy raz
# members dodane pierwszy raz
# pilot dodane pierwszy raz
# copilot dodane pierwszy raz
# mechanic dodane pierwszy raz
# and dodane pierwszy raz
# steward dodane pierwszy raz
# most dodane pierwszy raz
# of już jest
# the już jest
# passengers dodane pierwszy raz
# were już jest
# my już jest
# teammates dodane pierwszy raz
# but już jest
# we już jest
# were już jest
# also dodane pierwszy raz
# accompanied dodane pierwszy raz
# by dodane pierwszy raz
# friends dodane pierwszy raz
# family dodane pierwszy raz
# members już jest
# and już jest
# other dodane pierwszy raz
# supporters dodane pierwszy raz
# of już jest
# the już jest
# team już jest
# including już jest
# my już jest
# mother dodane pierwszy raz
# eugenia dodane pierwszy raz
# and już jest
# my już jest
# younger dodane pierwszy raz
# sister dodane pierwszy raz
# susy dodane pierwszy raz
# who dodane pierwszy raz
# were już jest
# sitting dodane pierwszy raz
# across dodane pierwszy raz
# the już jest
# aisle dodane pierwszy raz
# and już jest
# one już jest
# row dodane pierwszy raz
# in już jest
# front dodane pierwszy raz
# of już jest
# me dodane pierwszy raz
# our już jest
# original dodane pierwszy raz
# itinerary dodane pierwszy raz
# was już jest
# to już jest
# fly dodane pierwszy raz
# nonstop dodane pierwszy raz
# to już jest
# santiago już jest
# a już jest
# trip dodane pierwszy raz
# of już jest
# about już jest
# three dodane pierwszy raz
# and już jest
# a już jest
# half dodane pierwszy raz
# hours dodane pierwszy raz
# but już jest
# after dodane pierwszy raz
# just dodane pierwszy raz
# a już jest
# few dodane pierwszy raz
# hours już jest
# of już jest
# flying już jest
# reports dodane pierwszy raz
# of już jest
# bad dodane pierwszy raz
# weather dodane pierwszy raz
# in już jest
# the już jest
# mountains dodane pierwszy raz
# ahead dodane pierwszy raz
# forced dodane pierwszy raz
# the już jest
# fairchild już jest
# s dodane pierwszy raz
# pilot już jest
# julio dodane pierwszy raz
# ferradas dodane pierwszy raz
# to już jest
# put dodane pierwszy raz
# the już jest
# plane dodane pierwszy raz
# down dodane pierwszy raz
# in już jest
# the już jest
# old już jest
# spanish dodane pierwszy raz
# colonial dodane pierwszy raz
# town dodane pierwszy raz
# of już jest
# mendoza dodane pierwszy raz
# which dodane pierwszy raz
# lies dodane pierwszy raz
# just już jest
# east dodane pierwszy raz
# of już jest
# the już jest
# andean dodane pierwszy raz
# foothills dodane pierwszy raz
# we już jest
# landed dodane pierwszy raz
# in już jest
# mendoza już jest
# at dodane pierwszy raz
# lunchtime dodane pierwszy raz
# with dodane pierwszy raz
# hopes dodane pierwszy raz
# that już jest
# we już jest
# would dodane pierwszy raz
# be dodane pierwszy raz
# back dodane pierwszy raz
# in już jest
# the już jest
# air dodane pierwszy raz
# in już jest
# a już jest
# few już jest
# hours już jest
# but już jest
# the już jest
# weather już jest
# reports już jest
# were już jest
# not dodane pierwszy raz
# encouraging dodane pierwszy raz
# and już jest
# it już jest
# was już jest
# soon dodane pierwszy raz
# clear dodane pierwszy raz
# that już jest
# we już jest
# would już jest
# have dodane pierwszy raz
# to już jest
# stay dodane pierwszy raz
# the już jest
# night dodane pierwszy raz
# none dodane pierwszy raz
# of już jest
# us dodane pierwszy raz
# liked dodane pierwszy raz
# the już jest
# idea dodane pierwszy raz
# of już jest
# losing dodane pierwszy raz
# a już jest
# day już jest
# from dodane pierwszy raz
# our już jest
# trip już jest
# but już jest
# mendoza już jest
# was już jest
# a już jest
# charming dodane pierwszy raz
# place dodane pierwszy raz
# so już jest
# we już jest
# decided dodane pierwszy raz
# to już jest
# make już jest
# the już jest
# best dodane pierwszy raz
# of już jest
# our już jest
# time dodane pierwszy raz
# there już jest
# some dodane pierwszy raz
# of już jest
# the już jest
# guys dodane pierwszy raz
# relaxed dodane pierwszy raz
# in już jest
# sidewalk dodane pierwszy raz
# caf dodane pierwszy raz
# s już jest
# along dodane pierwszy raz
# mendoza już jest
# s już jest
# broad dodane pierwszy raz
# tree dodane pierwszy raz
# lined dodane pierwszy raz
# boulevards dodane pierwszy raz
# or dodane pierwszy raz
# went dodane pierwszy raz
# sightseeing dodane pierwszy raz
# in już jest
# the już jest
# city dodane pierwszy raz
# s już jest
# historic dodane pierwszy raz
# neighborhoods dodane pierwszy raz
# i dodane pierwszy raz
# spent dodane pierwszy raz
# the już jest
# afternoon dodane pierwszy raz
# with już jest
# some już jest
# friends już jest
# watching dodane pierwszy raz
# an już jest
# auto dodane pierwszy raz
# race dodane pierwszy raz
# at już jest
# a już jest
# track dodane pierwszy raz
# outside dodane pierwszy raz
# of już jest
# town już jest
# in już jest
# the już jest
# evening dodane pierwszy raz
# we już jest
# went już jest
# to już jest
# a już jest
# movie dodane pierwszy raz
# while dodane pierwszy raz
# some już jest
# of już jest
# the już jest
# others dodane pierwszy raz
# went już jest
# dancing dodane pierwszy raz
# with już jest
# some już jest
# argentinean dodane pierwszy raz
# girls dodane pierwszy raz
# they dodane pierwszy raz
# had już jest
# met dodane pierwszy raz
# my już jest
# mother już jest
# and już jest
# susy już jest
# spent już jest
# their dodane pierwszy raz
# time już jest
# exploring dodane pierwszy raz
# mendoza już jest
# s już jest
# quaint dodane pierwszy raz
# gift dodane pierwszy raz
# shops dodane pierwszy raz
# buying dodane pierwszy raz
# presents dodane pierwszy raz
# for dodane pierwszy raz
# friends już jest
# in już jest
# chile już jest
# and już jest
# souvenirs dodane pierwszy raz
# for już jest
# the już jest
# people już jest
# at już jest
# home dodane pierwszy raz
# my już jest
# mother już jest
# was już jest
# especially dodane pierwszy raz
# pleased dodane pierwszy raz
# to już jest
# find dodane pierwszy raz
# a już jest
# pair dodane pierwszy raz
# of już jest
# red dodane pierwszy raz
# baby dodane pierwszy raz
# shoes dodane pierwszy raz
# in już jest
# a już jest
# small dodane pierwszy raz
# boutique dodane pierwszy raz
# which już jest
# she dodane pierwszy raz
# thought dodane pierwszy raz
# would już jest
# make już jest
# the już jest
# perfect dodane pierwszy raz
# gift już jest
# for już jest
# my już jest
# sister już jest
# graciela dodane pierwszy raz
# s już jest
# new dodane pierwszy raz
# baby już jest
# boy dodane pierwszy raz
# most już jest
# of już jest
# us już jest
# slept dodane pierwszy raz
# late dodane pierwszy raz
# the już jest
# next dodane pierwszy raz
# morning dodane pierwszy raz
# and już jest
# when dodane pierwszy raz
# we już jest
# woke dodane pierwszy raz
# we już jest
# were już jest
# anxious dodane pierwszy raz
# to już jest
# leave dodane pierwszy raz
# but już jest
# there już jest
# was już jest
# still dodane pierwszy raz
# no dodane pierwszy raz
# word dodane pierwszy raz
# about już jest
# our już jest
# departure dodane pierwszy raz
# so już jest
# we już jest
# all dodane pierwszy raz
# went już jest
# our już jest
# separate dodane pierwszy raz
# ways dodane pierwszy raz
# to już jest
# see dodane pierwszy raz
# a już jest
# little dodane pierwszy raz
# more dodane pierwszy raz
# of już jest
# mendoza już jest
# finally dodane pierwszy raz
# we już jest
# received dodane pierwszy raz
# word już jest
# to już jest
# gather dodane pierwszy raz
# at już jest
# the już jest
# airport dodane pierwszy raz
# at już jest
# p dodane pierwszy raz
# m dodane pierwszy raz
# sharp dodane pierwszy raz
# but już jest
# we już jest
# arrived dodane pierwszy raz
# only dodane pierwszy raz
# to już jest
# discover dodane pierwszy raz
# that już jest
# ferradas już jest
# and już jest
# his dodane pierwszy raz
# copilot już jest
# dante dodane pierwszy raz
# lagurara dodane pierwszy raz
# had już jest
# not już jest
# yet dodane pierwszy raz
# decided już jest
# whether dodane pierwszy raz
# or już jest
# not już jest
# we już jest
# would już jest
# fly już jest
# we już jest
# reacted dodane pierwszy raz
# to już jest
# this dodane pierwszy raz
# news dodane pierwszy raz
# with już jest
# frustration dodane pierwszy raz
# and już jest
# anger dodane pierwszy raz
# but już jest
# none już jest
# of już jest
# us już jest
# understood dodane pierwszy raz
# the już jest
# difficult dodane pierwszy raz
# decision dodane pierwszy raz
# confronting dodane pierwszy raz
# the już jest
# pilots dodane pierwszy raz
# the już jest
# weather już jest
# reports już jest
# that już jest
# morning już jest
# warned dodane pierwszy raz
# of już jest
# some już jest
# turbulence dodane pierwszy raz
# along już jest
# our już jest
# flight już jest
# path dodane pierwszy raz
# but już jest
# after już jest
# speaking dodane pierwszy raz
# with już jest
# the już jest
# pilot już jest
# of już jest
# a już jest
# cargo dodane pierwszy raz
# plane już jest
# that już jest
# had już jest
# just już jest
# flown dodane pierwszy raz
# in już jest
# from już jest
# santiago już jest
# ferradas już jest
# was już jest
# confident dodane pierwszy raz
# the już jest
# fairchild już jest
# could dodane pierwszy raz
# fly już jest
# safely dodane pierwszy raz
# above dodane pierwszy raz
# the już jest
# weather już jest
# the już jest
# more już jest
# troubling dodane pierwszy raz
# problem dodane pierwszy raz
# was już jest
# the już jest
# time już jest
# of już jest
# day już jest
# it już jest
# was już jest
# already dodane pierwszy raz
# early dodane pierwszy raz
# afternoon już jest
# by już jest
# the już jest
# time już jest
# the już jest
# passengers już jest
# were już jest
# boarded dodane pierwszy raz
# and już jest
# all już jest
# the już jest
# necessary dodane pierwszy raz
# arrangements dodane pierwszy raz
# were już jest
# made dodane pierwszy raz
# with już jest
# airport już jest
# officials dodane pierwszy raz
# it już jest
# would już jest
# be już jest
# well dodane pierwszy raz
# past dodane pierwszy raz
# two dodane pierwszy raz
# o dodane pierwszy raz
# clock dodane pierwszy raz
# in już jest
# the już jest
# afternoon już jest
# warm dodane pierwszy raz
# air już jest
# rises dodane pierwszy raz
# from już jest
# the już jest
# argentine dodane pierwszy raz
# foothills już jest
# and już jest
# meets dodane pierwszy raz
# the już jest
# frigid dodane pierwszy raz
# air już jest
# above już jest
# the już jest
# snowline dodane pierwszy raz
# to już jest
# create dodane pierwszy raz
# treacherous dodane pierwszy raz
# instability dodane pierwszy raz
# in już jest
# the już jest
# atmosphere dodane pierwszy raz
# above już jest
# the już jest
# mountains już jest
# our już jest
# pilots już jest
# knew dodane pierwszy raz
# that już jest
# this już jest
# was już jest
# the już jest
# most już jest
# dangerous dodane pierwszy raz
# time już jest
# to już jest
# fly już jest
# across już jest
# the już jest
# andes już jest
# there już jest
# was już jest
# no już jest
# way dodane pierwszy raz
# to już jest
# predict dodane pierwszy raz
# where dodane pierwszy raz
# these dodane pierwszy raz
# swirling dodane pierwszy raz
# currents dodane pierwszy raz
# might dodane pierwszy raz
# strike dodane pierwszy raz
# and już jest
# if dodane pierwszy raz
# they już jest
# got dodane pierwszy raz
# hold dodane pierwszy raz
# of już jest
# us już jest
# our już jest
# plane już jest
# would już jest
# be już jest
# tossed dodane pierwszy raz
# around dodane pierwszy raz
# like dodane pierwszy raz
# a już jest
# toy dodane pierwszy raz
# on już jest
# the już jest
# other już jest
# hand dodane pierwszy raz
# we już jest
# couldn dodane pierwszy raz
# t dodane pierwszy raz
# stay już jest
# put już jest
# in już jest
# mendoza już jest
# our już jest
# aircraft dodane pierwszy raz
# was już jest
# a już jest
# fairchild już jest
# f dodane pierwszy raz
# that już jest
# we już jest
# had już jest
# leased dodane pierwszy raz
# from już jest
# the już jest
# uruguayan dodane pierwszy raz
# air już jest
# force dodane pierwszy raz
# the już jest
# laws dodane pierwszy raz
# of już jest
# argentina dodane pierwszy raz
# forbade dodane pierwszy raz
# a już jest
# foreign dodane pierwszy raz
# military dodane pierwszy raz
# aircraft już jest
# to już jest
# stay już jest
# on już jest
# argentine już jest
# soil dodane pierwszy raz
# longer dodane pierwszy raz
# than dodane pierwszy raz
# twenty dodane pierwszy raz
# four już jest
# hours już jest
# since dodane pierwszy raz
# our już jest
# time już jest
# was już jest
# almost dodane pierwszy raz
# up dodane pierwszy raz
# ferradas już jest
# and już jest
# lagurara już jest
# had już jest
# to już jest
# make już jest
# a już jest
# fast dodane pierwszy raz
# decision już jest
# should dodane pierwszy raz
# they już jest
# take dodane pierwszy raz
# off dodane pierwszy raz
# for już jest
# santiago już jest
# and już jest
# brave dodane pierwszy raz
# the już jest
# afternoon już jest
# skies dodane pierwszy raz
# or już jest
# fly już jest
# the już jest
# fairchild już jest
# back już jest
# to już jest
# montevideo już jest
# and już jest
# put już jest
# an już jest
# end dodane pierwszy raz
# to już jest
# our już jest
# vacation dodane pierwszy raz
# as dodane pierwszy raz
# the już jest
# pilots już jest
# pondered dodane pierwszy raz
# the już jest
# options dodane pierwszy raz
# our już jest
# impatience dodane pierwszy raz
# grew dodane pierwszy raz
# we już jest
# had już jest
# already już jest
# lost dodane pierwszy raz
# a już jest
# day już jest
# of już jest
# our już jest
# chilean już jest
# trip już jest
# and już jest
# we już jest
# were już jest
# frustrated dodane pierwszy raz
# by już jest
# the już jest
# thought już jest
# of już jest
# losing już jest
# more już jest
# we już jest
# were już jest
# bold dodane pierwszy raz
# young już jest
# men już jest
# fearless dodane pierwszy raz
# and już jest
# full dodane pierwszy raz
# of już jest
# ourselves dodane pierwszy raz
# and już jest
# it już jest
# angered dodane pierwszy raz
# us już jest
# that już jest
# our już jest
# vacation już jest
# was już jest
# slipping dodane pierwszy raz
# away dodane pierwszy raz
# because dodane pierwszy raz
# of już jest
# what dodane pierwszy raz
# we już jest
# regarded dodane pierwszy raz
# as już jest
# the już jest
# timidity dodane pierwszy raz
# of już jest
# our już jest
# pilots już jest
# we już jest
# did dodane pierwszy raz
# not już jest
# hide dodane pierwszy raz
# these już jest
# feelings dodane pierwszy raz
# when już jest
# we już jest
# saw dodane pierwszy raz
# the już jest
# pilots już jest
# at już jest
# the już jest
# airport już jest
# we już jest
# jeered dodane pierwszy raz
# and już jest
# whistled dodane pierwszy raz
# at już jest
# them dodane pierwszy raz
# we już jest
# teased dodane pierwszy raz
# them już jest
# and już jest
# questioned dodane pierwszy raz
# their już jest
# competence dodane pierwszy raz
# we już jest
# hired dodane pierwszy raz
# you dodane pierwszy raz
# to już jest
# take już jest
# us już jest
# to już jest
# chile już jest
# someone dodane pierwszy raz
# shouted dodane pierwszy raz
# and już jest
# that już jest
# s już jest
# what już jest
# we już jest
# want dodane pierwszy raz
# you już jest
# to już jest
# do dodane pierwszy raz
# there już jest
# is dodane pierwszy raz
# no już jest
# way już jest
# to już jest
# know dodane pierwszy raz
# whether już jest
# or już jest
# not już jest
# our już jest
# behavior dodane pierwszy raz
# influenced dodane pierwszy raz
# their już jest
# decision już jest
# it już jest
# did już jest
# seem dodane pierwszy raz
# to już jest
# unsettle dodane pierwszy raz
# them już jest
# but już jest
# finally już jest
# after już jest
# one już jest
# last dodane pierwszy raz
# consultation dodane pierwszy raz
# with już jest
# lagurara już jest
# ferradas już jest
# glanced dodane pierwszy raz
# around już jest
# at już jest
# the już jest
# crowd dodane pierwszy raz
# waiting dodane pierwszy raz
# restlessly dodane pierwszy raz
# for już jest
# an już jest
# answer dodane pierwszy raz
# and już jest
# announced dodane pierwszy raz
# that już jest
# the już jest
# flight już jest
# to już jest
# santiago już jest
# would już jest
# continue dodane pierwszy raz
# we już jest
# greeted dodane pierwszy raz
# this już jest
# news już jest
# with już jest
# a już jest
# rowdy dodane pierwszy raz
# cheer dodane pierwszy raz
# the już jest
# fairchild już jest
# finally już jest
# departed dodane pierwszy raz
# from już jest
# mendoza już jest
# airport już jest
# at już jest
# eighteen dodane pierwszy raz
# minutes dodane pierwszy raz
# after już jest
# two już jest
# o już jest
# clock już jest
# local dodane pierwszy raz
# time już jest
# as już jest
# we już jest
# climbed dodane pierwszy raz
# the już jest
# plane już jest
# banked dodane pierwszy raz
# steeply dodane pierwszy raz
# into dodane pierwszy raz
# a już jest
# left dodane pierwszy raz
# turn dodane pierwszy raz
# and już jest
# soon już jest
# we już jest
# were już jest
# flying już jest
# south dodane pierwszy raz
# with już jest
# the już jest
# argentine już jest
# andes już jest
# rising dodane pierwszy raz
# to już jest
# our już jest
# right dodane pierwszy raz
# on już jest
# the już jest
# western dodane pierwszy raz
# horizon dodane pierwszy raz
# through dodane pierwszy raz
# the już jest
# windows dodane pierwszy raz
# on już jest
# the już jest
# right już jest
# side dodane pierwszy raz
# of już jest
# the już jest
# fuselage dodane pierwszy raz
# i już jest
# gazed dodane pierwszy raz
# at już jest
# the już jest
# mountains już jest
# which już jest
# thundered dodane pierwszy raz
# up już jest
# from już jest
# the już jest
# dry dodane pierwszy raz
# plateau dodane pierwszy raz
# below dodane pierwszy raz
# us już jest
# like już jest
# a już jest
# black dodane pierwszy raz
# mirage dodane pierwszy raz
# so już jest
# bleak dodane pierwszy raz
# and już jest
# majestic dodane pierwszy raz
# so już jest
# astonishingly dodane pierwszy raz
# vast dodane pierwszy raz
# and już jest
# huge dodane pierwszy raz
# that już jest
# the już jest
# simple dodane pierwszy raz
# sight dodane pierwszy raz
# of już jest
# them już jest
# made już jest
# my już jest
# heart dodane pierwszy raz
# race już jest
# rooted dodane pierwszy raz
# in już jest
# massive dodane pierwszy raz
# swells dodane pierwszy raz
# of już jest
# bedrock dodane pierwszy raz
# with już jest
# colossal dodane pierwszy raz
# bases dodane pierwszy raz
# that już jest
# spread dodane pierwszy raz
# for już jest
# miles dodane pierwszy raz
# their już jest
# black już jest
# ridges dodane pierwszy raz
# soared dodane pierwszy raz
# up już jest
# from już jest
# the już jest
# flatlands dodane pierwszy raz
# one już jest
# peak dodane pierwszy raz
# crowding dodane pierwszy raz
# the już jest
# next już jest
# so już jest
# that już jest
# they już jest
# seemed dodane pierwszy raz
# to już jest
# form dodane pierwszy raz
# a już jest
# colossal już jest
# fortress dodane pierwszy raz
# wall dodane pierwszy raz
# i już jest
# was już jest
# not już jest
# a już jest
# poetically dodane pierwszy raz
# inclined dodane pierwszy raz
# young już jest
# man dodane pierwszy raz
# but już jest
# there już jest
# seemed już jest
# to już jest
# be już jest
# a już jest
# warning dodane pierwszy raz
# in już jest
# the już jest
# great dodane pierwszy raz
# authority dodane pierwszy raz
# with już jest
# which już jest
# these już jest
# mountains już jest
# held dodane pierwszy raz
# their już jest
# ground dodane pierwszy raz
# and już jest
# it już jest
# was już jest
# impossible dodane pierwszy raz
# not już jest
# to już jest
# think dodane pierwszy raz
# of już jest
# them już jest
# as już jest
# living dodane pierwszy raz
# things dodane pierwszy raz
# with już jest
# minds dodane pierwszy raz
# and już jest
# hearts dodane pierwszy raz
# and już jest
# an już jest
# old już jest
# brooding dodane pierwszy raz
# awareness dodane pierwszy raz
# no już jest
# wonder dodane pierwszy raz
# the już jest
# ancients dodane pierwszy raz
# thought już jest
# of już jest
# these już jest
# mountains już jest
# as już jest
# holy dodane pierwszy raz
# places dodane pierwszy raz
# as już jest
# the już jest
# doorstep dodane pierwszy raz
# to już jest
# heaven dodane pierwszy raz
# and już jest
# as już jest
# the już jest
# dwelling dodane pierwszy raz
# place już jest
# of już jest
# the już jest
# gods dodane pierwszy raz
# uruguay dodane pierwszy raz
# is już jest
# a już jest
# low dodane pierwszy raz
# lying dodane pierwszy raz
# country dodane pierwszy raz
# and już jest
# like już jest
# most już jest
# of już jest
# my już jest
# friends już jest
# on już jest
# the już jest
# plane już jest
# my już jest
# knowledge dodane pierwszy raz
# of już jest
# the już jest
# andes już jest
# or już jest
# of już jest
# any dodane pierwszy raz
# mountains już jest
# at już jest
# all już jest
# was już jest
# limited dodane pierwszy raz
# to już jest
# what już jest
# i już jest
# had już jest
# read dodane pierwszy raz
# in już jest
# books dodane pierwszy raz
# in już jest
# school dodane pierwszy raz
# we już jest
# learned dodane pierwszy raz
# that już jest
# the już jest
# andes już jest
# range dodane pierwszy raz
# was już jest
# the już jest
# most już jest
# extensive dodane pierwszy raz
# mountain dodane pierwszy raz
# system dodane pierwszy raz
# in już jest
# the już jest
# world dodane pierwszy raz
# running dodane pierwszy raz
# the już jest
# length dodane pierwszy raz
# of już jest
# south już jest
# america dodane pierwszy raz
# from już jest
# venezuela dodane pierwszy raz
# in już jest
# the już jest
# north dodane pierwszy raz
# to już jest
# the już jest
# southern dodane pierwszy raz
# tip dodane pierwszy raz
# of już jest
# the już jest
# continent dodane pierwszy raz
# in już jest
# tierra dodane pierwszy raz
# del dodane pierwszy raz
# fuego dodane pierwszy raz
# i już jest
# also już jest
# knew już jest
# that już jest
# the już jest
# andes już jest
# are dodane pierwszy raz
# the już jest
# second dodane pierwszy raz
# highest dodane pierwszy raz
# mountain już jest
# range już jest
# on już jest
# the już jest
# planet dodane pierwszy raz
# in już jest
# terms dodane pierwszy raz
# of już jest
# average dodane pierwszy raz
# elevation dodane pierwszy raz
# only już jest
# the już jest
# himalayas dodane pierwszy raz
# are już jest
# higher dodane pierwszy raz
# i już jest
# had już jest
# heard dodane pierwszy raz
# people już jest
# refer dodane pierwszy raz
# to już jest
# the już jest
# andes już jest
# as już jest
# one już jest
# of już jest
# the już jest
# earth dodane pierwszy raz
# s już jest
# great już jest
# geological dodane pierwszy raz
# wonders dodane pierwszy raz
# and już jest
# the już jest
# view dodane pierwszy raz
# from już jest
# the już jest
# airplane dodane pierwszy raz
# gave dodane pierwszy raz
# me już jest
# a już jest
# visceral dodane pierwszy raz
# understanding dodane pierwszy raz
# of już jest
# what już jest
# that już jest
# meant dodane pierwszy raz
# to już jest
# the już jest
# north już jest
# south już jest
# and już jest
# west dodane pierwszy raz
# the już jest
# mountains już jest
# sprawled dodane pierwszy raz
# as już jest
# far dodane pierwszy raz
# as już jest
# the już jest
# eye dodane pierwszy raz
# could już jest
# see już jest
# and już jest
# even dodane pierwszy raz
# though dodane pierwszy raz
# they już jest
# were już jest
# many dodane pierwszy raz
# miles już jest
# away już jest
# their już jest
# height dodane pierwszy raz
# and już jest
# mass dodane pierwszy raz
# made już jest
# them już jest
# seem już jest
# impassable dodane pierwszy raz
# in już jest
# fact dodane pierwszy raz
# as już jest
# far już jest
# as już jest
# we już jest
# were już jest
# concerned dodane pierwszy raz
# they już jest
# were już jest
# our już jest
# destination już jest
# santiago już jest
# lies już jest
# almost już jest
# exactly dodane pierwszy raz
# due dodane pierwszy raz
# west już jest
# of już jest
# mendoza już jest
# but już jest
# the już jest
# region dodane pierwszy raz
# of już jest
# the już jest
# andes już jest
# that już jest
# separates dodane pierwszy raz
# the już jest
# two już jest
# cities dodane pierwszy raz
# is już jest
# one już jest
# of już jest
# the już jest
# highest już jest
# sections dodane pierwszy raz
# of już jest
# the już jest
# entire dodane pierwszy raz
# chain dodane pierwszy raz
# and już jest
# home już jest
# to już jest
# some już jest
# of już jest
# the już jest
# tallest dodane pierwszy raz
# mountains już jest
# in już jest
# the już jest
# world już jest
# somewhere dodane pierwszy raz
# out dodane pierwszy raz
# there już jest
# for już jest
# example dodane pierwszy raz
# was już jest
# aconcagua dodane pierwszy raz
# the już jest
# highest już jest
# mountain już jest
# in już jest
# the już jest
# western już jest
# hemisphere dodane pierwszy raz
# and już jest
# one już jest
# of już jest
# the już jest
# seven dodane pierwszy raz
# tallest już jest
# on już jest
# the już jest
# planet już jest
# with już jest
# a już jest
# summit dodane pierwszy raz
# of już jest
# feet dodane pierwszy raz
# it już jest
# stands dodane pierwszy raz
# just już jest
# feet już jest
# shy dodane pierwszy raz
# of już jest
# everest dodane pierwszy raz
# and już jest
# it już jest
# has dodane pierwszy raz
# giants dodane pierwszy raz
# for już jest
# neighbors dodane pierwszy raz
# including już jest
# the już jest
# foot dodane pierwszy raz
# mount dodane pierwszy raz
# mercedario dodane pierwszy raz
# and już jest
# mount już jest
# tupongato dodane pierwszy raz
# which już jest
# stands już jest
# feet już jest
# tall dodane pierwszy raz
# surrounding dodane pierwszy raz
# these już jest
# behemoths dodane pierwszy raz
# are już jest
# other już jest
# great już jest
# peaks dodane pierwszy raz
# with już jest
# elevations dodane pierwszy raz
# of już jest
# between dodane pierwszy raz
# and już jest
# feet już jest
# which już jest
# no już jest
# one już jest
# in już jest
# those już jest
# wild dodane pierwszy raz
# reaches dodane pierwszy raz
# had już jest
# ever dodane pierwszy raz
# bothered dodane pierwszy raz
# to już jest
# name dodane pierwszy raz
# with już jest
# such już jest
# towering dodane pierwszy raz
# summits dodane pierwszy raz
# rising już jest
# along już jest
# the już jest
# way już jest
# there już jest
# was już jest
# no już jest
# chance dodane pierwszy raz
# that już jest
# the już jest
# fairchild już jest
# with już jest
# its już jest
# maximum dodane pierwszy raz
# cruising dodane pierwszy raz
# altitude dodane pierwszy raz
# of już jest
# feet już jest
# could już jest
# fly już jest
# a już jest
# direct dodane pierwszy raz
# east już jest
# west już jest
# route dodane pierwszy raz
# to już jest
# santiago już jest
# instead dodane pierwszy raz
# the już jest
# pilots już jest
# had już jest
# charted dodane pierwszy raz
# a już jest
# course dodane pierwszy raz
# that już jest
# would już jest
# take już jest
# us już jest
# about już jest
# one już jest
# hundred dodane pierwszy raz
# miles już jest
# south już jest
# of już jest
# mendoza już jest
# to już jest
# planch dodane pierwszy raz
# n dodane pierwszy raz
# pass dodane pierwszy raz
# a już jest
# narrow dodane pierwszy raz
# corridor dodane pierwszy raz
# through już jest
# the już jest
# mountains już jest
# with już jest
# ridges już jest
# low już jest
# enough dodane pierwszy raz
# for już jest
# the już jest
# plane już jest
# to już jest
# clear już jest
# we już jest
# would już jest
# fly już jest
# south już jest
# along już jest
# the już jest
# eastern dodane pierwszy raz
# foothills już jest
# of już jest
# the już jest
# andes już jest
# with już jest
# the już jest
# mountains już jest
# always dodane pierwszy raz
# on już jest
# our już jest
# right już jest
# until dodane pierwszy raz
# we już jest
# reached dodane pierwszy raz
# the już jest
# pass już jest
# then dodane pierwszy raz
# we już jest
# d dodane pierwszy raz
# turn już jest
# west już jest
# and już jest
# weave dodane pierwszy raz
# our już jest
# way już jest
# through już jest
# the już jest
# mountains już jest
# when już jest
# we już jest
# had już jest
# cleared dodane pierwszy raz
# the już jest
# mountains już jest
# on już jest
# the już jest
# chilean już jest
# side już jest
# we już jest
# would już jest
# turn już jest
# right już jest
# and już jest
# fly już jest
# north już jest
# to już jest
# santiago już jest
# the już jest
# flight już jest
# should już jest
# take już jest
# about już jest
# an już jest
# hour dodane pierwszy raz
# and już jest
# a już jest
# half już jest
# we już jest
# would już jest
# be już jest
# in już jest
# santiago już jest
# before już jest
# dark dodane pierwszy raz
# on już jest
# this już jest
# first dodane pierwszy raz
# leg dodane pierwszy raz
# of już jest
# the już jest
# trip już jest
# the już jest
# skies już jest
# were już jest
# calm dodane pierwszy raz
# and już jest
# in już jest
# less dodane pierwszy raz
# than już jest
# an już jest
# hour już jest
# we już jest
# had już jest
# reached już jest
# the już jest
# vicinity dodane pierwszy raz
# of już jest
# planch już jest
# n już jest
# pass już jest
# i już jest
# didn dodane pierwszy raz
# t już jest
# know już jest
# the już jest
# name już jest
# of już jest
# the już jest
# pass już jest
# of już jest
# course już jest
# or już jest
# any już jest
# of już jest
# the już jest
# flight już jest
# details dodane pierwszy raz
# but już jest
# i już jest
# couldn już jest
# t już jest
# help dodane pierwszy raz
# noticing dodane pierwszy raz
# that już jest
# after już jest
# flying już jest
# for już jest
# miles już jest
# with już jest
# the już jest
# mountains już jest
# always już jest
# off już jest
# in już jest
# the już jest
# western już jest
# distance dodane pierwszy raz
# we już jest
# had już jest
# banked już jest
# to już jest
# the już jest
# west już jest
# and już jest
# were już jest
# now dodane pierwszy raz
# flying już jest
# directly dodane pierwszy raz
# into już jest
# the już jest
# heart już jest
# of już jest
# the już jest
# cordillera dodane pierwszy raz
# i już jest
# was już jest
# sitting już jest
# in już jest
# a już jest
# window dodane pierwszy raz
# seat dodane pierwszy raz
# on już jest
# the już jest
# left już jest
# side już jest
# of już jest
# the już jest
# plane już jest
# and już jest
# as już jest
# i już jest
# watched dodane pierwszy raz
# the już jest
# flat dodane pierwszy raz
# featureless dodane pierwszy raz
# landscape dodane pierwszy raz
# below już jest
# seemed już jest
# to już jest
# leap dodane pierwszy raz
# up już jest
# from już jest
# the już jest
# earth już jest
# first już jest
# to już jest
# form już jest
# rugged dodane pierwszy raz
# foothills już jest
# then już jest
# heaving dodane pierwszy raz
# and już jest
# buckling dodane pierwszy raz
# up już jest
# into już jest
# the już jest
# awesome dodane pierwszy raz
# convolutions dodane pierwszy raz
# of już jest
# true dodane pierwszy raz
# mountains już jest
# shark dodane pierwszy raz
# finned dodane pierwszy raz
# ridges już jest
# raised dodane pierwszy raz
# themselves dodane pierwszy raz
# up już jest
# like już jest
# soaring dodane pierwszy raz
# black już jest
# sails dodane pierwszy raz
# menacing dodane pierwszy raz
# peaks już jest
# pushed dodane pierwszy raz
# up już jest
# like już jest
# gigantic dodane pierwszy raz
# spearheads dodane pierwszy raz
# or już jest
# the już jest
# broken dodane pierwszy raz
# blades dodane pierwszy raz
# of już jest
# hatchets dodane pierwszy raz
# narrow już jest
# glacial dodane pierwszy raz
# valleys dodane pierwszy raz
# gashed dodane pierwszy raz
# the już jest
# steep dodane pierwszy raz
# slopes dodane pierwszy raz
# forming dodane pierwszy raz
# rows dodane pierwszy raz
# of już jest
# deep dodane pierwszy raz
# winding dodane pierwszy raz
# snow dodane pierwszy raz
# packed dodane pierwszy raz
# corridors dodane pierwszy raz
# that już jest
# stacked dodane pierwszy raz
# and już jest
# folded dodane pierwszy raz
# one już jest
# upon dodane pierwszy raz
# the już jest
# other już jest
# to już jest
# create już jest
# a już jest
# wild już jest
# endless dodane pierwszy raz
# maze dodane pierwszy raz
# of już jest
# ice dodane pierwszy raz
# and już jest
# rock dodane pierwszy raz
# in już jest
# the już jest
# southern już jest
# hemisphere już jest
# winter dodane pierwszy raz
# had już jest
# given dodane pierwszy raz
# way już jest
# to już jest
# early już jest
# spring dodane pierwszy raz
# but już jest
# in już jest
# the już jest
# andes już jest
# temperatures dodane pierwszy raz
# still już jest
# routinely dodane pierwszy raz
# dipped dodane pierwszy raz
# to już jest
# degrees dodane pierwszy raz
# below już jest
# zero dodane pierwszy raz
# fahrenheit dodane pierwszy raz
# and już jest
# the już jest
# air już jest
# was już jest
# as już jest
# dry już jest
# as już jest
# a już jest
# desert dodane pierwszy raz
# i już jest
# knew już jest
# that już jest
# avalanches dodane pierwszy raz
# blizzards dodane pierwszy raz
# and już jest
# killing dodane pierwszy raz
# gale dodane pierwszy raz
# force już jest
# winds dodane pierwszy raz
# were już jest
# common dodane pierwszy raz
# in już jest
# these już jest
# mountains już jest
# and już jest
# that już jest
# the już jest
# previous dodane pierwszy raz
# winter już jest
# had już jest
# been dodane pierwszy raz
# one już jest
# of już jest
# the już jest
# most już jest
# severe dodane pierwszy raz
# on już jest
# record dodane pierwszy raz
# with już jest
# snowfalls dodane pierwszy raz
# in już jest
# some już jest
# places już jest
# of już jest
# several dodane pierwszy raz
# hundred już jest
# feet już jest
# i już jest
# saw już jest
# no już jest
# color dodane pierwszy raz
# at już jest
# all już jest
# in już jest
# the już jest
# mountains już jest
# just już jest
# muted dodane pierwszy raz
# patches dodane pierwszy raz
# of już jest
# black już jest
# and już jest
# gray dodane pierwszy raz
# there już jest
# was już jest
# no już jest
# softness dodane pierwszy raz
# no już jest
# life dodane pierwszy raz
# only już jest
# rock już jest
# and już jest
# snow już jest
# and już jest
# ice już jest
# and już jest
# as już jest
# i już jest
# looked dodane pierwszy raz
# down już jest
# into już jest
# all już jest
# that już jest
# rugged już jest
# wildness dodane pierwszy raz
# i już jest
# had już jest
# to już jest
# laugh dodane pierwszy raz
# at już jest
# the już jest
# arrogance dodane pierwszy raz
# of już jest
# anyone dodane pierwszy raz
# who już jest
# had już jest
# ever już jest
# thought już jest
# that już jest
# human dodane pierwszy raz
# beings dodane pierwszy raz
# have już jest
# conquered dodane pierwszy raz
# the już jest
# earth już jest
# watching już jest
# out już jest
# the już jest
# window już jest
# i już jest
# noticed dodane pierwszy raz
# that już jest
# wisps dodane pierwszy raz
# of już jest
# fog dodane pierwszy raz
# were już jest
# gathering dodane pierwszy raz
# then już jest
# i już jest
# felt dodane pierwszy raz
# a już jest
# hand już jest
# on już jest
# my już jest
# shoulder dodane pierwszy raz
# switch dodane pierwszy raz
# seats dodane pierwszy raz
# with już jest
# me już jest
# nando dodane pierwszy raz
# i już jest
# want już jest
# to już jest
# look dodane pierwszy raz
# at już jest
# the już jest
# mountains już jest
# it już jest
# was już jest
# my już jest
# friend dodane pierwszy raz
# panchito dodane pierwszy raz
# who już jest
# was już jest
# sitting już jest
# in już jest
# the już jest
# aisle już jest
# seat już jest
# beside dodane pierwszy raz
# me już jest
# i już jest
# nodded dodane pierwszy raz
# and już jest
# rose dodane pierwszy raz
# from już jest
# my już jest
# seat już jest
# when już jest
# i już jest
# stood dodane pierwszy raz
# to już jest
# change dodane pierwszy raz
# places już jest
# someone już jest
# yelled dodane pierwszy raz
# think już jest
# fast już jest
# nando już jest
# and już jest
# i już jest
# turned dodane pierwszy raz
# just już jest
# in już jest
# time już jest
# to już jest
# catch dodane pierwszy raz
# a już jest
# rugby już jest
# ball dodane pierwszy raz
# someone już jest
# had już jest
# tossed już jest
# from już jest
# the już jest
# rear dodane pierwszy raz
# of już jest
# the już jest
# cabin dodane pierwszy raz
# i już jest
# passed dodane pierwszy raz
# the już jest
# ball już jest
# forward dodane pierwszy raz
# and już jest
# then już jest
# sank dodane pierwszy raz
# into już jest
# my już jest
# seat już jest
# all już jest
# around już jest
# us już jest
# there już jest
# was już jest
# laughing dodane pierwszy raz
# and już jest
# talking dodane pierwszy raz
# people już jest
# were już jest
# moving dodane pierwszy raz
# from już jest
# seat już jest
# to już jest
# seat już jest
# visiting dodane pierwszy raz
# friends już jest
# up już jest
# and już jest
# down już jest
# the już jest
# aisle już jest
# some już jest
# friends już jest
# including już jest
# my już jest
# oldest dodane pierwszy raz
# amigo dodane pierwszy raz
# guido dodane pierwszy raz
# magri dodane pierwszy raz
# were już jest
# in już jest
# the już jest
# back już jest
# of już jest
# the już jest
# plane już jest
# playing dodane pierwszy raz
# cards dodane pierwszy raz
# with już jest
# some już jest
# crew już jest
# members już jest
# including już jest
# the już jest
# flight już jest
# steward już jest
# but już jest
# when już jest
# the już jest
# ball już jest
# began dodane pierwszy raz
# bouncing dodane pierwszy raz
# around już jest
# the już jest
# cabin już jest
# the już jest
# steward już jest
# stepped dodane pierwszy raz
# forward już jest
# and już jest
# tried dodane pierwszy raz
# to już jest
# calm już jest
# things już jest
# down już jest
# put już jest
# the już jest
# ball już jest
# away już jest
# he dodane pierwszy raz
# shouted już jest
# settle dodane pierwszy raz
# down już jest
# and już jest
# please dodane pierwszy raz
# take już jest
# your dodane pierwszy raz
# seats już jest
# but już jest
# we już jest
# were już jest
# young już jest
# rugby już jest
# players dodane pierwszy raz
# traveling dodane pierwszy raz
# with już jest
# our już jest
# friends już jest
# and już jest
# we już jest
# did już jest
# not już jest
# want już jest
# to już jest
# settle już jest
# down już jest
# our już jest
# team już jest
# the już jest
# old już jest
# christians już jest
# from już jest
# montevideo już jest
# was już jest
# one już jest
# of już jest
# the już jest
# best już jest
# rugby już jest
# teams dodane pierwszy raz
# in już jest
# uruguay już jest
# and już jest
# we już jest
# took dodane pierwszy raz
# our już jest
# regular dodane pierwszy raz
# matches dodane pierwszy raz
# seriously dodane pierwszy raz
# but już jest
# in już jest
# chile już jest
# we już jest
# would już jest
# be już jest
# playing już jest
# an już jest
# exhibition już jest
# match już jest
# only już jest
# so już jest
# this już jest
# trip już jest
# was już jest
# really dodane pierwszy raz
# a już jest
# holiday dodane pierwszy raz
# for już jest
# us już jest
# and już jest
# on już jest
# the już jest
# plane już jest
# there już jest
# was już jest
# the już jest
# feeling dodane pierwszy raz
# that już jest
# the już jest
# holiday już jest
# had już jest
# already już jest
# begun dodane pierwszy raz
# it już jest
# was już jest
# a już jest
# fine dodane pierwszy raz
# thing dodane pierwszy raz
# to już jest
# be już jest
# traveling już jest
# with już jest
# my już jest
# friends już jest
# these już jest
# friends już jest
# especially już jest
# we już jest
# had już jest
# been już jest
# through już jest
# so już jest
# much dodane pierwszy raz
# together dodane pierwszy raz
# all już jest
# the już jest
# years dodane pierwszy raz
# of już jest
# learning dodane pierwszy raz
# and już jest
# training dodane pierwszy raz
# the już jest
# heartbreaking dodane pierwszy raz
# losses dodane pierwszy raz
# the już jest
# hard dodane pierwszy raz
# fought dodane pierwszy raz
# wins dodane pierwszy raz
# we już jest
# had już jest
# grown dodane pierwszy raz
# up już jest
# as już jest
# teammates już jest
# drawing dodane pierwszy raz
# from już jest
# each dodane pierwszy raz
# other już jest
# s już jest
# strengths dodane pierwszy raz
# learning już jest
# to już jest
# trust dodane pierwszy raz
# one już jest
# another dodane pierwszy raz
# when już jest
# the już jest
# pressure dodane pierwszy raz
# was już jest
# on już jest
# but już jest
# the już jest
# game dodane pierwszy raz
# of już jest
# rugby już jest
# had już jest
# not już jest
# only już jest
# shaped dodane pierwszy raz
# our już jest
# friendships dodane pierwszy raz
# it już jest
# had już jest
# shaped już jest
# our już jest
# characters dodane pierwszy raz
# and już jest
# brought dodane pierwszy raz
# us już jest
# together już jest
# as już jest
# brothers dodane pierwszy raz
# many już jest
# of już jest
# us już jest
# on już jest
# the już jest
# old już jest
# christians już jest
# had już jest
# known dodane pierwszy raz
# each już jest
# other już jest
# for już jest
# more już jest
# than już jest
# ten dodane pierwszy raz
# years już jest
# since już jest
# our już jest
# days dodane pierwszy raz
# as już jest
# schoolboy dodane pierwszy raz
# ruggers dodane pierwszy raz
# playing już jest
# under dodane pierwszy raz
# the już jest
# guidance dodane pierwszy raz
# of już jest
# the już jest
# irish dodane pierwszy raz
# christian dodane pierwszy raz
# brothers już jest
# at już jest
# the już jest
# stella dodane pierwszy raz
# maris dodane pierwszy raz
# school już jest
# the już jest
# christian już jest
# brothers już jest
# had już jest
# come dodane pierwszy raz
# to już jest
# uruguay już jest
# from już jest
# ireland dodane pierwszy raz
# in już jest
# the już jest
# early już jest
# s już jest
# at już jest
# the już jest
# invitation dodane pierwszy raz
# of już jest
# a już jest
# group dodane pierwszy raz
# of już jest
# catholic dodane pierwszy raz
# parents dodane pierwszy raz
# who już jest
# wanted dodane pierwszy raz
# them już jest
# to już jest
# found dodane pierwszy raz
# a już jest
# private dodane pierwszy raz
# catholic już jest
# school już jest
# in już jest
# montevideo już jest
# five już jest
# irish już jest
# brothers już jest
# answered dodane pierwszy raz
# the już jest
# call dodane pierwszy raz
# and już jest
# in już jest
# they już jest
# created dodane pierwszy raz
# the już jest
# stella już jest
# maris już jest
# college dodane pierwszy raz
# a już jest
# private już jest
# school już jest
# for już jest
# boys dodane pierwszy raz
# between już jest
# the już jest
# ages dodane pierwszy raz
# of już jest
# nine dodane pierwszy raz
# and już jest
# sixteen dodane pierwszy raz
# located dodane pierwszy raz
# in już jest
# the już jest
# carrasco dodane pierwszy raz
# neighborhood dodane pierwszy raz
# where już jest
# most już jest
# of już jest
# the już jest
# students dodane pierwszy raz
# lived dodane pierwszy raz
# for już jest
# the już jest
# christian już jest
# brothers już jest
# the już jest
# first już jest
# goal dodane pierwszy raz
# of już jest
# a już jest
# catholic już jest
# education dodane pierwszy raz
# was już jest
# to już jest
# build dodane pierwszy raz
# character dodane pierwszy raz
# not już jest
# intellect dodane pierwszy raz
# and już jest
# their już jest
# teaching dodane pierwszy raz
# methods dodane pierwszy raz
# stressed dodane pierwszy raz
# discipline dodane pierwszy raz
# piety dodane pierwszy raz
# selflessness dodane pierwszy raz
# and już jest
# respect dodane pierwszy raz
# to już jest
# promote dodane pierwszy raz
# these już jest
# values dodane pierwszy raz
# outside już jest
# the już jest
# classroom dodane pierwszy raz
# the już jest
# brothers już jest
# discouraged dodane pierwszy raz
# our już jest
# natural dodane pierwszy raz
# south już jest
# american dodane pierwszy raz
# passion dodane pierwszy raz
# for już jest
# soccer dodane pierwszy raz
# a już jest
# game już jest
# that już jest
# in już jest
# their już jest
# view już jest
# fostered dodane pierwszy raz
# selfishness dodane pierwszy raz
# and już jest
# egotism dodane pierwszy raz
# and już jest
# steered dodane pierwszy raz
# us już jest
# toward dodane pierwszy raz
# the już jest
# rougher dodane pierwszy raz
# earthier dodane pierwszy raz
# game już jest
# of już jest
# rugby już jest
# for już jest
# generations dodane pierwszy raz
# rugby już jest
# had już jest
# been już jest
# an już jest
# irish już jest
# passion już jest
# but już jest
# it już jest
# was już jest
# virtually dodane pierwszy raz
# unknown dodane pierwszy raz
# in już jest
# our już jest
# country już jest
# at już jest
# first już jest
# the już jest
# game już jest
# seemed już jest
# strange dodane pierwszy raz
# to już jest
# us już jest
# so już jest
# brutal dodane pierwszy raz
# and już jest
# painful dodane pierwszy raz
# to już jest
# play już jest
# so już jest
# much już jest
# pushing dodane pierwszy raz
# and już jest
# shoving dodane pierwszy raz
# and już jest
# so już jest
# little już jest
# of już jest
# soccer już jest
# s już jest
# wide dodane pierwszy raz
# open dodane pierwszy raz
# flair dodane pierwszy raz
# but już jest
# the już jest
# christian już jest
# brothers już jest
# firmly dodane pierwszy raz
# believed dodane pierwszy raz
# that już jest
# the już jest
# qualities dodane pierwszy raz
# required dodane pierwszy raz
# to już jest
# master dodane pierwszy raz
# the już jest
# sport dodane pierwszy raz
# were już jest
# the już jest
# same dodane pierwszy raz
# characteristics dodane pierwszy raz
# one już jest
# needed dodane pierwszy raz
# to już jest
# live dodane pierwszy raz
# a już jest
# decent dodane pierwszy raz
# catholic już jest
# life już jest
# humility dodane pierwszy raz
# tenacity dodane pierwszy raz
# self dodane pierwszy raz
# discipline już jest
# and już jest
# devotion dodane pierwszy raz
# to już jest
# others już jest
# and już jest
# they już jest
# were już jest
# determined dodane pierwszy raz
# that już jest
# we już jest
# would już jest
# play już jest
# the już jest
# game już jest
# and już jest
# play już jest
# it już jest
# well już jest
# it już jest
# did już jest
# not już jest
# take już jest
# us już jest
# long dodane pierwszy raz
# to już jest
# learn dodane pierwszy raz
# that już jest
# once dodane pierwszy raz
# the już jest
# christian już jest
# brothers już jest
# set dodane pierwszy raz
# their już jest
# minds już jest
# to już jest
# a już jest
# purpose dodane pierwszy raz
# there już jest
# was już jest
# little już jest
# that już jest
# could już jest
# sway dodane pierwszy raz
# them już jest
# so już jest
# we już jest
# set już jest
# aside dodane pierwszy raz
# our już jest
# soccer już jest
# balls dodane pierwszy raz
# and już jest
# acquainted dodane pierwszy raz
# ourselves już jest
# with już jest
# the już jest
# fat dodane pierwszy raz
# pointed dodane pierwszy raz
# pigskin dodane pierwszy raz
# used dodane pierwszy raz
# in już jest
# rugby już jest
# in już jest
# long już jest
# tough dodane pierwszy raz
# practices dodane pierwszy raz
# on już jest
# the już jest
# fields dodane pierwszy raz
# behind dodane pierwszy raz
# the już jest
# school już jest
# the już jest
# brothers już jest
# started dodane pierwszy raz
# from już jest
# scratch dodane pierwszy raz
# drilling dodane pierwszy raz
# us już jest
# in już jest
# all już jest
# the już jest
# rugged już jest
# intricacies dodane pierwszy raz
# of już jest
# the już jest
# game już jest
# mucks dodane pierwszy raz
# and już jest
# rauls dodane pierwszy raz
# scrumdowns dodane pierwszy raz
# and już jest
# lineouts dodane pierwszy raz
# how dodane pierwszy raz
# to już jest
# kick dodane pierwszy raz
# and już jest
# pass już jest
# and już jest
# tackle dodane pierwszy raz
# we już jest
# learned już jest
# that już jest
# rugby już jest
# players już jest
# wore dodane pierwszy raz
# no już jest
# pads dodane pierwszy raz
# or już jest
# helmets dodane pierwszy raz
# but już jest
# still już jest
# we już jest
# were już jest
# expected dodane pierwszy raz
# to już jest
# play już jest
# aggressively dodane pierwszy raz
# and już jest
# with już jest
# great już jest
# physical dodane pierwszy raz
# courage dodane pierwszy raz
# but już jest
# rugby już jest
# was już jest
# more już jest
# than już jest
# a już jest
# game już jest
# of już jest
# brute dodane pierwszy raz
# strength dodane pierwszy raz
# it już jest
# required już jest
# sound dodane pierwszy raz
# strategy dodane pierwszy raz
# quick dodane pierwszy raz
# thinking dodane pierwszy raz
# and już jest
# agility dodane pierwszy raz
# most już jest
# of już jest
# all już jest
# the już jest
# game już jest
# demanded dodane pierwszy raz
# that już jest
# teammates już jest
# develop dodane pierwszy raz
# an już jest
# unshakeable dodane pierwszy raz
# sense dodane pierwszy raz
# of już jest
# trust już jest
# they już jest
# explained dodane pierwszy raz
# that już jest
# when już jest
# one już jest
# of już jest
# our już jest
# teammates już jest
# falls dodane pierwszy raz
# or już jest
# is już jest
# knocked dodane pierwszy raz
# to już jest
# the już jest
# ground już jest
# he już jest
# becomes dodane pierwszy raz
# grass dodane pierwszy raz
# this już jest
# was już jest
# their już jest
# way już jest
# of już jest
# saying dodane pierwszy raz
# that już jest
# a już jest
# downed dodane pierwszy raz
# player dodane pierwszy raz
# can dodane pierwszy raz
# be już jest
# stomped dodane pierwszy raz
# on już jest
# and już jest
# trampled dodane pierwszy raz
# by już jest
# the już jest
# opposition dodane pierwszy raz
# as już jest
# if już jest
# he już jest
# were już jest
# part dodane pierwszy raz
# of już jest
# the już jest
# turf dodane pierwszy raz
# one już jest
# of już jest
# the już jest
# first już jest
# things już jest
# they już jest
# taught dodane pierwszy raz
# us już jest
# was już jest
# how już jest
# to już jest
# behave dodane pierwszy raz
# when już jest
# a już jest
# teammate dodane pierwszy raz
# becomes już jest
# grass już jest
# you już jest
# must dodane pierwszy raz
# become dodane pierwszy raz
# his już jest
# ...
# to już jest
# us już jest
# in już jest
# one już jest
# holy już jest
# book już jest
# or już jest
# another już jest
# and już jest
# who już jest
# tinkers dodane pierwszy raz
# with już jest
# our już jest
# lives już jest
# according już jest
# to już jest
# some już jest
# divine dodane pierwszy raz
# plan już jest
# as już jest
# if już jest
# we już jest
# were już jest
# characters już jest
# in już jest
# a już jest
# play już jest
# how już jest
# can już jest
# i już jest
# make już jest
# sense już jest
# of już jest
# a już jest
# god już jest
# who już jest
# sets już jest
# one już jest
# religion już jest
# above już jest
# the już jest
# rest już jest
# who już jest
# answers już jest
# one już jest
# prayer już jest
# and już jest
# ignores dodane pierwszy raz
# another już jest
# who już jest
# sends dodane pierwszy raz
# sixteen już jest
# young już jest
# men już jest
# home już jest
# and już jest
# leaves dodane pierwszy raz
# twenty już jest
# nine już jest
# others już jest
# dead już jest
# on już jest
# a już jest
# mountain już jest
# there już jest
# was już jest
# a już jest
# time już jest
# when już jest
# i już jest
# wanted już jest
# to już jest
# know już jest
# that już jest
# god już jest
# but już jest
# i już jest
# realize już jest
# now już jest
# that już jest
# what już jest
# i już jest
# really już jest
# wanted już jest
# was już jest
# the już jest
# comfort już jest
# of już jest
# certainty już jest
# the już jest
# knowledge już jest
# that już jest
# my już jest
# god już jest
# was już jest
# the już jest
# true już jest
# god już jest
# and już jest
# that już jest
# in już jest
# the już jest
# end już jest
# he już jest
# would już jest
# reward dodane pierwszy raz
# me już jest
# for już jest
# my już jest
# faithfulness dodane pierwszy raz
# now już jest
# i już jest
# understand już jest
# that już jest
# to już jest
# be już jest
# certain już jest
# about już jest
# god już jest
# about już jest
# anything już jest
# is już jest
# impossible już jest
# i już jest
# have już jest
# lost już jest
# my już jest
# need już jest
# to już jest
# know już jest
# in już jest
# those już jest
# unforgettable dodane pierwszy raz
# conversations już jest
# i już jest
# had już jest
# with już jest
# arturo już jest
# as już jest
# he już jest
# lay już jest
# dying już jest
# he już jest
# told już jest
# me już jest
# the już jest
# best już jest
# way już jest
# to już jest
# find już jest
# faith już jest
# was już jest
# by już jest
# having już jest
# the już jest
# courage już jest
# to już jest
# doubt już jest
# i już jest
# remember już jest
# those już jest
# words już jest
# every już jest
# day już jest
# and już jest
# i już jest
# doubt już jest
# and już jest
# i już jest
# hope już jest
# and już jest
# in już jest
# this już jest
# crude już jest
# way już jest
# i już jest
# try już jest
# to już jest
# grope dodane pierwszy raz
# my już jest
# way już jest
# toward już jest
# truth już jest
# i już jest
# still już jest
# pray już jest
# the już jest
# prayers już jest
# i już jest
# learned już jest
# as już jest
# a już jest
# child już jest
# hail już jest
# marys już jest
# our już jest
# fathers już jest
# but już jest
# i już jest
# don już jest
# t już jest
# imagine już jest
# a już jest
# wise już jest
# heavenly dodane pierwszy raz
# father już jest
# listening już jest
# patiently już jest
# on już jest
# the już jest
# other już jest
# end już jest
# of już jest
# the już jest
# line już jest
# instead już jest
# i już jest
# imagine już jest
# love już jest
# an już jest
# ocean już jest
# of już jest
# love już jest
# the już jest
# very już jest
# source już jest
# of już jest
# love już jest
# and już jest
# i już jest
# imagine już jest
# myself już jest
# merging dodane pierwszy raz
# with już jest
# it już jest
# i już jest
# open już jest
# myself już jest
# to już jest
# it już jest
# i już jest
# try już jest
# to już jest
# direct już jest
# that już jest
# tide już jest
# of już jest
# love już jest
# toward już jest
# the już jest
# people już jest
# who już jest
# are już jest
# close już jest
# to już jest
# me już jest
# hoping już jest
# to już jest
# protect już jest
# them już jest
# and już jest
# bind dodane pierwszy raz
# them już jest
# to już jest
# me już jest
# forever już jest
# and już jest
# connect już jest
# us już jest
# all już jest
# to już jest
# whatever już jest
# there już jest
# is już jest
# in już jest
# the już jest
# world już jest
# that już jest
# is już jest
# eternal już jest
# this już jest
# is już jest
# a już jest
# very już jest
# private już jest
# thing już jest
# for już jest
# me już jest
# and już jest
# i już jest
# don już jest
# t już jest
# try już jest
# to już jest
# analyze dodane pierwszy raz
# what już jest
# it już jest
# means już jest
# i już jest
# simply już jest
# like już jest
# the już jest
# way już jest
# it już jest
# makes już jest
# me już jest
# feel już jest
# when już jest
# i już jest
# pray już jest
# this już jest
# way już jest
# i już jest
# feel już jest
# as już jest
# if już jest
# i już jest
# am już jest
# connected już jest
# to już jest
# something już jest
# good już jest
# and już jest
# whole już jest
# and już jest
# powerful już jest
# in już jest
# the już jest
# mountains już jest
# it już jest
# was już jest
# love już jest
# that już jest
# kept już jest
# me już jest
# connected już jest
# to już jest
# the już jest
# world już jest
# of już jest
# the już jest
# living już jest
# courage już jest
# or już jest
# cleverness już jest
# wouldn już jest
# t już jest
# have już jest
# saved już jest
# me już jest
# i już jest
# had już jest
# no już jest
# expertise już jest
# to już jest
# draw już jest
# on już jest
# so już jest
# i już jest
# relied dodane pierwszy raz
# upon już jest
# the już jest
# trust już jest
# i już jest
# felt już jest
# in już jest
# my już jest
# love już jest
# for już jest
# my już jest
# father już jest
# and już jest
# my już jest
# future już jest
# and już jest
# that już jest
# trust już jest
# led już jest
# me już jest
# home już jest
# since już jest
# then już jest
# it już jest
# has już jest
# led już jest
# me już jest
# to już jest
# a już jest
# deeper już jest
# understanding już jest
# of już jest
# who już jest
# i już jest
# am już jest
# and już jest
# what już jest
# it już jest
# means już jest
# to już jest
# be już jest
# human już jest
# now już jest
# i już jest
# am już jest
# convinced już jest
# that już jest
# if już jest
# there już jest
# is już jest
# something już jest
# divine już jest
# in już jest
# the już jest
# universe już jest
# the już jest
# only już jest
# way już jest
# i już jest
# will już jest
# find już jest
# it już jest
# is już jest
# through już jest
# the już jest
# love już jest
# i już jest
# feel już jest
# for już jest
# my już jest
# family już jest
# and już jest
# my już jest
# friends już jest
# and już jest
# through już jest
# the już jest
# simple już jest
# wonder już jest
# of już jest
# being już jest
# alive już jest
# i już jest
# don już jest
# t już jest
# need już jest
# any już jest
# other już jest
# wisdom już jest
# or już jest
# philosophy już jest
# than już jest
# this już jest
# my już jest
# duty już jest
# is już jest
# to już jest
# fill już jest
# my już jest
# time już jest
# on już jest
# earth już jest
# with już jest
# as już jest
# much już jest
# life już jest
# as już jest
# possible już jest
# to już jest
# become już jest
# a już jest
# little już jest
# more już jest
# human już jest
# every już jest
# day już jest
# and już jest
# to już jest
# understand już jest
# that już jest
# we już jest
# only już jest
# become już jest
# human już jest
# when już jest
# we już jest
# love już jest
# i już jest
# have już jest
# tried już jest
# to już jest
# love już jest
# my już jest
# friends już jest
# with już jest
# a już jest
# loyal dodane pierwszy raz
# and już jest
# generous już jest
# heart już jest
# i już jest
# have już jest
# loved już jest
# my już jest
# children już jest
# with już jest
# all już jest
# my już jest
# strength już jest
# and już jest
# i już jest
# have już jest
# loved już jest
# one już jest
# woman już jest
# and już jest
# that już jest
# has już jest
# filled już jest
# my już jest
# life już jest
# with już jest
# meaning już jest
# and już jest
# joy już jest
# i już jest
# have już jest
# suffered już jest
# great już jest
# losses już jest
# and już jest
# have już jest
# been już jest
# blessed już jest
# with już jest
# great już jest
# consolations dodane pierwszy raz
# but już jest
# whatever już jest
# life już jest
# may już jest
# give już jest
# me już jest
# or już jest
# take już jest
# away już jest
# this już jest
# is już jest
# the już jest
# simple już jest
# wisdom już jest
# that już jest
# will już jest
# always już jest
# light już jest
# my już jest
# life już jest
# i już jest
# have już jest
# loved już jest
# passionately dodane pierwszy raz
# fearlessly dodane pierwszy raz
# with już jest
# all już jest
# my już jest
# heart już jest
# and już jest
# all już jest
# my już jest
# soul już jest
# and już jest
# i już jest
# have już jest
# been już jest
# loved już jest
# in już jest
# return już jest
# for już jest
# me już jest
# this już jest
# is już jest
# enough już jest
# two już jest
# years już jest
# after już jest
# the już jest
# miracle już jest
# in już jest
# the już jest
# andes już jest
# my już jest
# father już jest
# and już jest
# i już jest
# returned już jest
# to już jest
# the już jest
# crash już jest
# site już jest
# in już jest
# the już jest
# high już jest
# andes już jest
# near już jest
# sosneado dodane pierwszy raz
# mountain już jest
# a już jest
# route już jest
# had już jest
# been już jest
# discovered już jest
# passable dodane pierwszy raz
# only już jest
# in już jest
# summer już jest
# leading już jest
# from już jest
# the już jest
# argentine już jest
# foothills już jest
# to już jest
# the już jest
# glacier już jest
# where już jest
# the już jest
# fairchild już jest
# lay już jest
# it już jest
# s już jest
# a już jest
# grueling już jest
# three już jest
# day już jest
# trip już jest
# that już jest
# begins już jest
# with już jest
# an już jest
# eight już jest
# hour już jest
# drive już jest
# in już jest
# off już jest
# road już jest
# vehicles dodane pierwszy raz
# across już jest
# the już jest
# rugged już jest
# terrain już jest
# of już jest
# the już jest
# andean już jest
# foothills już jest
# then już jest
# two już jest
# and już jest
# a już jest
# half już jest
# days już jest
# on już jest
# horseback już jest
# we już jest
# forded już jest
# a już jest
# swift już jest
# stream już jest
# then już jest
# rode dodane pierwszy raz
# specially już jest
# trained już jest
# andean już jest
# horses już jest
# along już jest
# steep już jest
# narrow już jest
# trails już jest
# that już jest
# wove dodane pierwszy raz
# up już jest
# into już jest
# the już jest
# mountains już jest
# above już jest
# hair już jest
# raising już jest
# drops już jest
# to już jest
# the już jest
# rocky już jest
# slopes już jest
# below już jest
# we już jest
# reached już jest
# the już jest
# base już jest
# of już jest
# the już jest
# glacier już jest
# at już jest
# midday już jest
# then już jest
# made już jest
# our już jest
# final już jest
# climb już jest
# to już jest
# the już jest
# gravesite już jest
# on już jest
# foot już jest
# the już jest
# grave już jest
# itself już jest
# built już jest
# just już jest
# after już jest
# our już jest
# rescue już jest
# by już jest
# air już jest
# force już jest
# members już jest
# from już jest
# uruguay już jest
# and już jest
# chile już jest
# sits już jest
# on już jest
# a już jest
# rocky już jest
# promontory dodane pierwszy raz
# jutting już jest
# above już jest
# the już jest
# snow już jest
# beneath już jest
# the już jest
# rocks już jest
# lie już jest
# susy już jest
# and już jest
# my już jest
# mother już jest
# along już jest
# with już jest
# the już jest
# remains już jest
# of już jest
# the już jest
# others już jest
# who już jest
# died już jest
# here już jest
# all już jest
# safely już jest
# out już jest
# of już jest
# reach już jest
# of już jest
# the już jest
# grinding już jest
# glacier już jest
# a już jest
# few już jest
# hundred już jest
# feet już jest
# away już jest
# it już jest
# s już jest
# a już jest
# simple już jest
# shrine dodane pierwszy raz
# just już jest
# a już jest
# pile już jest
# of już jest
# stones już jest
# and już jest
# a już jest
# small już jest
# steel już jest
# cross już jest
# rising już jest
# above już jest
# the już jest
# grave już jest
# my już jest
# father już jest
# brought już jest
# flowers już jest
# and już jest
# a już jest
# stainless dodane pierwszy raz
# steel już jest
# box już jest
# containing dodane pierwszy raz
# the już jest
# teddy dodane pierwszy raz
# bear już jest
# susy już jest
# had już jest
# slept już jest
# with już jest
# every już jest
# night już jest
# of już jest
# her już jest
# life już jest
# he już jest
# placed już jest
# these już jest
# gifts już jest
# on już jest
# the już jest
# grave już jest
# and już jest
# we już jest
# stood już jest
# there już jest
# quietly już jest
# in już jest
# the już jest
# silence już jest
# of już jest
# the już jest
# mountains już jest
# i już jest
# remembered już jest
# that już jest
# silence już jest
# so już jest
# well już jest
# a już jest
# constant już jest
# and już jest
# absolute już jest
# absence już jest
# of już jest
# sound już jest
# on już jest
# calm już jest
# days już jest
# you już jest
# hear już jest
# nothing już jest
# but już jest
# your już jest
# own już jest
# breathing już jest
# your już jest
# own już jest
# thoughts już jest
# my już jest
# father już jest
# s już jest
# face już jest
# was już jest
# pale już jest
# and już jest
# tears już jest
# wet już jest
# his już jest
# cheeks już jest
# as już jest
# we już jest
# shared już jest
# this już jest
# sad już jest
# reunion już jest
# but już jest
# i już jest
# felt już jest
# no już jest
# pain już jest
# or już jest
# grief już jest
# i już jest
# felt już jest
# tranquillity dodane pierwszy raz
# in już jest
# that już jest
# place już jest
# there już jest
# was już jest
# no już jest
# more już jest
# fear już jest
# there już jest
# or już jest
# suffering już jest
# or już jest
# struggle już jest
# the już jest
# dead już jest
# were już jest
# at już jest
# peace już jest
# the już jest
# pure już jest
# perfect już jest
# stillness dodane pierwszy raz
# of już jest
# the już jest
# mountains już jest
# had już jest
# returned już jest
# it już jest
# was już jest
# a już jest
# bright już jest
# clear już jest
# spring już jest
# day już jest
# my już jest
# father już jest
# turned już jest
# to już jest
# me już jest
# with już jest
# a już jest
# sad już jest
# smile już jest
# he już jest
# looked już jest
# at już jest
# the już jest
# glacier już jest
# at już jest
# the już jest
# black już jest
# peaks już jest
# above już jest
# us już jest
# at już jest
# the już jest
# wide już jest
# savage już jest
# andean już jest
# sky już jest
# and już jest
# i już jest
# know już jest
# he już jest
# was już jest
# trying już jest
# to już jest
# imagine już jest
# this już jest
# place już jest
# in już jest
# the już jest
# cold już jest
# months już jest
# of już jest
# early już jest
# spring już jest
# he już jest
# glanced już jest
# at już jest
# the już jest
# remains już jest
# of już jest
# the już jest
# fuselage już jest
# was już jest
# he już jest
# seeing już jest
# young już jest
# boys już jest
# huddled już jest
# inside już jest
# frightened już jest
# faces już jest
# in już jest
# the już jest
# dark już jest
# and już jest
# the już jest
# cold już jest
# listening już jest
# to już jest
# the już jest
# howl już jest
# of już jest
# the już jest
# wind już jest
# and już jest
# the już jest
# rumble już jest
# of już jest
# distant już jest
# avalanches już jest
# with już jest
# nothing już jest
# to już jest
# depend już jest
# on już jest
# but już jest
# each już jest
# other już jest
# did już jest
# he już jest
# imagine już jest
# me już jest
# in już jest
# this już jest
# hard już jest
# place już jest
# so już jest
# frightened już jest
# so już jest
# impossibly już jest
# far już jest
# from już jest
# home już jest
# and już jest
# longing już jest
# so już jest
# desperately już jest
# to już jest
# be już jest
# with już jest
# him już jest
# my już jest
# father już jest
# didn już jest
# t już jest
# say już jest
# he już jest
# only już jest
# smiled już jest
# tenderly już jest
# took już jest
# me już jest
# by już jest
# the już jest
# arm już jest
# and już jest
# whispered już jest
# nando już jest
# now już jest
# i już jest
# understand już jest
# we już jest
# stayed już jest
# at już jest
# the już jest
# gravesite już jest
# for już jest
# an już jest
# hour już jest
# or już jest
# so już jest
# then już jest
# made już jest
# our już jest
# way już jest
# back już jest
# down już jest
# to już jest
# the już jest
# horses już jest
# we już jest
# never już jest
# thought już jest
# for już jest
# a już jest
# moment już jest
# about już jest
# moving już jest
# the już jest
# bodies już jest
# of już jest
# our już jest
# loved już jest
# ones już jest
# to już jest
# a już jest
# cemetery dodane pierwszy raz
# in już jest
# the już jest
# civilized już jest
# world już jest
# as już jest
# we już jest
# descended już jest
# the już jest
# mountain już jest
# the już jest
# grandeur już jest
# of już jest
# the już jest
# andes już jest
# thundered już jest
# all już jest
# around już jest
# us już jest
# so już jest
# silent już jest
# so już jest
# massive już jest
# so już jest
# perfect już jest
# and już jest
# neither już jest
# of już jest
# us już jest
# could już jest
# imagine już jest
# a już jest
# more już jest
# majestic już jest
# shrine już jest
# 11
